# %%
import pandas as pd

df = pd.DataFrame(
    columns=['week', 'Societal Impact', 'Investigative Problem Solving',
             'Data Preparation', 'Machine Teaching', 'Data Visualization',
             'Reporting', 'Personal Leadership', 'Football Match Prediction'],
    data=[
        {
            'week': 1,
            'Societal Impact': 'Undefined',
            'Investigative Problem Solving': 'Undefined',
            'Data Preparation': 'Undefined',
            'Machine Teaching': 'Undefined',
            'Data Visualization': 'Undefined',
            'Reporting': 'Undefined',
            'Personal Leadership': 'Undefined',
            'Football Match Prediction': 'Undefined'
        },
        {
            'week': 2,
            'Societal Impact': 'Undefined',
            'Investigative Problem Solving': 'Undefined',
            'Data Preparation': 'Undefined',
            'Machine Teaching': 'Undefined',
            'Data Visualization': 'Undefined',
            'Reporting': 'Undefined',
            'Personal Leadership': 'Undefined',
            'Football Match Prediction': 'Orienting'
        },
        {
            'week': 3,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Undefined',
            'Data Preparation': 'Orienting',
            'Machine Teaching': 'Undefined',
            'Data Visualization': 'Undefined',
            'Reporting': 'Undefined',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Orienting'
        },
        {
            'week': 4,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Undefined',
            'Data Preparation': 'Orienting',
            'Machine Teaching': 'Undefined',
            'Data Visualization': 'Undefined',
            'Reporting': 'Orienting',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Orienting'
        },
        {
            'week': 5,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Beginning',
            'Machine Teaching': 'Orienting',
            'Data Visualization': 'Beginning',
            'Reporting': 'Orienting',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 6,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Beginning',
            'Machine Teaching': 'Orienting',
            'Data Visualization': 'Beginning',
            'Reporting': 'Orienting',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 7,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Beginning',
            'Machine Teaching': 'Orienting',
            'Data Visualization': 'Beginning',
            'Reporting': 'Orienting',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 8,
            'Societal Impact': 'Orienting',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Beginning',
            'Machine Teaching': 'Orienting',
            'Data Visualization': 'Beginning',
            'Reporting': 'Orienting',
            'Personal Leadership': 'Orienting',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 9,
            'Societal Impact': 'Beginning',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Proficient',
            'Machine Teaching': 'Beginning',
            'Data Visualization': 'Proficient',
            'Reporting': 'Beginning',
            'Personal Leadership': 'Beginning',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 10,
            'Societal Impact': 'Beginning',
            'Investigative Problem Solving': 'Orienting',
            'Data Preparation': 'Proficient',
            'Machine Teaching': 'Beginning',
            'Data Visualization': 'Proficient',
            'Reporting': 'Beginning',
            'Personal Leadership': 'Beginning',
            'Football Match Prediction': 'Beginning'
        },
        {
            'week': 11,
            'Societal Impact': 'Beginning',
            'Investigative Problem Solving': 'Beginning',
            'Data Preparation': 'Proficient',
            'Machine Teaching': 'Proficient',
            'Data Visualization': 'Proficient',
            'Reporting': 'Beginning',
            'Personal Leadership': 'Proficient',
            'Football Match Prediction': 'Proficient'
        },
        {
            'week': 12,
            'Societal Impact': 'Beginning',
            'Investigative Problem Solving': 'Beginning',
            'Data Preparation': 'Proficient',
            'Machine Teaching': 'Proficient',
            'Data Visualization': 'Proficient',
            'Reporting': 'Beginning',
            'Personal Leadership': 'Proficient',
            'Football Match Prediction': 'Proficient'
        },
    ]
)

mapping = {
    'Undefined': 0,
    'Orienting': 1,
    'Beginning': 2,
    'Proficient': 3,
    'Advanced': 4,
}
for col in df.columns[1:]:
    df[col] = df[col].map(mapping)

# plot the data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for col in df.columns[1:]:
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.set_xticks(df['week'])

    # put a green line on proficient
    ax.axhline(3, color='green', linestyle='--')

    ax.set_xticklabels(df['week'])
    ax.set_xlabel('Week')
    ax.set_ylabel('Level')
    ax.set_ylim(-0.5, 4.5)
    ax.set_yticks([0, 1, 2, 3, 4])
    ax.set_yticklabels(['Undefined', 'Orienting', 'Beginning', 'Proficient', 'Advanced'])
    
    # invert background to be white and grid lines gray
    ax.set_facecolor('white')

    # add border
    for spine in ax.spines.values():
        spine.set_edgecolor('grey')
        
    colors = {
        0: 'grey',
        1: 'red',
        2: 'orange',
        3: 'green',
        4: 'blue'
    }
    for i, label in enumerate(ax.get_yticklabels()):
        label.set_color(colors[i])

    plt.tight_layout()
    plt.title(f"'{col}' progress from week 1 to week 12")

    # fill area below the line depending on the y level
    for i, row in df.iterrows():
        if i == 11:
            break
        current_level = row[col]
        next_level = df.at[i+1, col]

        ax.fill_between(
            x=[row['week'], row['week']+1],
            y1=-0.5,
            y2=row[col],
            alpha=0.4,
            color=colors[row[col]]
        )

    # plot the line as a step
    ax.step(df['week'], df[col], where='post', color='black', marker='o')

    plt.savefig(f'progress_{col}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# generate a barchart of the latest week
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 5))
df.iloc[-1, 1:].plot(kind='bar', ax=ax)
ax.set_xticklabels(df.columns[1:], rotation=45)
ax.axhline(3, color='green', linestyle='--')
colors = {
    0: 'grey',
    1: 'red',
    2: 'orange',
    3: 'green',
    4: 'blue'
}
for i, rect in enumerate(ax.patches):
    rect.set_color(colors[df.iloc[-1, i+1]])

# align the xlabels
ax.set_xticklabels(df.columns[1:], rotation=45, ha='right')

ax.set_ylabel('Level')
ax.set_ylim(0, 4.5)
ax.set_yticks([0, 1, 2, 3, 4])
ax.set_yticklabels(['Undefined', 'Orienting', 'Beginning', 'Proficient', 'Advanced'])
# put the colors on the yticklabels
for i, label in enumerate(ax.get_yticklabels()):
    label.set_color(colors[i])
# add title
ax.set_title('Progress as of Week 12 (02 Dec 2023)')
plt.tight_layout()
plt.savefig(f'progress_latest.png', dpi=300)
plt.show()
